# %% [markdown]
# # 데이터 수집
#
# 연구를 하는 과정에서 데이터 수집은 정말 중요합니다.
#
# 데이터를 수집하는 과정은 정말 다양하지만, 제가 생각하는 수집 방법은 크게 2가지 입니다.
#
# 1. 제공된 데이터 다운
# ex) AI-Hub, bigkinds (뉴스 데이터 제공)
#
# 2. 데이터 직접 수집
#
#   2.1  API가 존재하는가?
#   ex) reddit, bigkinds (유료인가..?)
#
#   2.2 다른 사람이 먼저 구현한 코드 (github)
#
#   2.3  * 크롤링 (최후의 보루)
# 제공된 데이터를 다운 받을 때도 크롤링을 사용하는 경우가 존재 (너무 많을 때 Selenium을 이용해서 사람이 하는 것처럼 다운)

# %% [markdown]
# # google-play-scraper (API)
# 설치
#
#
# https://play.google.com/store/games?hl=en

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

# %% [markdown]
# # 데이터 수집

# %%
from google_play_scraper import Sort, reviews_all
# API에서 제공되는 데이터는 application의 모든 리뷰를 가져오는 것은 아닙니다.
# 또한 시도마다 서버에서 제공되는 데이터 개수가 달라질 수 있습니다.
# reviews_all안의 값들은 영어 데이터를 수집하기 위해 설정되어 있습니다.
raw_data = reviews_all(
    'com.codemasters.F1Mobile', # app
    # 리뷰수가 많으면 코랩에서 돌아가는데 시간 많이 걸리므로, 로컬에서 하거나 리뷰 적은 게임으로 시도
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT # defaults to Sort.MOST_RELEVANT
)

# 댓글, 별점, 공감수, 시간

# %% [markdown]
# # 수집된 데이터 출력

# %%
from pprint import pprint
pprint(raw_data[:5])
# Out:
# [{'appVersion': '5.2.47',
#   'at': datetime.datetime(2023, 9, 20, 18, 27, 49),
#   'content': 'In a word: unfinished. The gameplay is great, I love the career '
#              'mode, I love exploring all the tracks, the different weather is '
#              'amazing and the punishment for going off-track or into other '
#              'drivers is properly severe. HOWEVER, this game is so unstable. '
#              "It crashes on a whim, it will drop frames like it's Snoop Dogg "
#              "and the frames are hot. It's so fun which gets it that second "
#              "star, but PLEASE, just polish this game and it's an easy 5.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.2.47',
#   'reviewId': '2c3f4701-e36d-4ffa-95fb-49f53e66799d',
#   'score': 2,
#   'thumbsUpCount': 92,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWalZB0iOfUMswFEqyJDv4DsF3SdiwJ0hacS0UuY88qejVn',
#   'userName': 'Aidan Bell'},
#  {'appVersion': '5.2.47',
#   'at': datetime.datetime(2023, 10, 3, 2, 45, 36),
#   'content': 'Really alot of fun. Pretty glitchy for me though. Very often, '
#              'the game gets stuck on the "searching for opponent" screen and '
#              "very frequent connectivity issues. Despite the problems, I've "
#              'played multiple times a week for a couple of years. Still love '
#              "it. Would love it more if they'd fix the reliability issues.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.2.47',
#   'reviewId': '6c5af7ab-9694-4c3c-8b7f-85ddb3ca109a',
#   'score': 4,
#   'thumbsUpCount': 27,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIKxGqRMW_lzR5VxuGxRZuZ3lKvoWhhdSMfc90qD4hl=mo',
#   'userName': 'Nathan Poulter'},
#  {'appVersion': '5.2.47',
#   'at': datetime.datetime(2023, 9, 5, 22, 28, 27),
#   'content': "It's looks pretty interesting overall. I've barely played it for "
#              'a minutes. The main menu feels a little busy and controller '
#              'settings are practically non existent it would be nice to be '
#              "able to customize them. Aside from this it's a good game overall "
#              "it just feels like it's needs more quality of life improvements",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.2.47',
#   'reviewId': '877ac69d-bce2-480e-a40f-bdad060b91d2',
#   'score': 4,
#   'thumbsUpCount': 100,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUbgBEtQOyR2hFyJFgCspivX4GI7M9ZFiTCS836CnMRapQ',
#   'userName': 'Ruben Saldana'},
#  {'appVersion': '5.1.11',
#   'at': datetime.datetime(2023, 7, 30, 15, 54, 29),
#   'content': "The gameplay's pretty fun, but the UI needs work. It's unstable "
#              'and can lag frequently. The layers palette in the livery '
#              "customization is a buggy mess, even with a stylus. It's behavior "
#              'seems to change everytime you enter the game. All it wants to do '
#              "is duplicate layers in one session, and then doesn't let you do "
#              'anything except scroll through the layers the next. Aside from '
#              'those issues, pretty solid effort.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.1.11',
#   'reviewId': 'b9989a3c-866e-4425-a768-e9dc6852e331',
#   'score': 3,
#   'thumbsUpCount': 288,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVtfx2qD8cP6kZJib9pAe0-PxaVJxBDQbACRQDiULnziPo',
#   'userName': 'Cecil Torres'},
#  {'appVersion': '5.1.11',
#   'at': datetime.datetime(2023, 8, 21, 23, 33, 18),
#   'content': 'Overall great fun, but the ads to watch for free tokens and '
#              'coins rarely load when clicking on the icon to play the ad '
#              'streak. I usually need to kill the app and reopen it, only for '
#              'it to eventually work maybe 25% of the time. Please fix this as '
#              "it is very frustrating and also doesn't allow me to obtain more "
#              "coins or tokens and boxes because the ads won't load. And yes, I "
#              'have tried on both WiFi and mobile network connections, but the '
#              'issue persists. Edit: ad playback has been fixed.',
#   'repliedAt': datetime.datetime(2022, 5, 13, 15, 1, 49),
#   'replyContent': "Hello, we're sorry that you've experienced issues. Please "
#                   'use the "Help & Support" function in the game, and give us '
#                   "more details about the problem you're facing.",
#   'reviewCreatedVersion': '5.1.11',
#   'reviewId': 'b0411bec-e7a2-4def-b1bb-dd562d8a6af1',
#   'score': 4,
#   'thumbsUpCount': 312,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVtsCDReywslQ2MMs3tdujiIECAJIEmj4WIux2SkIj6SSaY',
#   'userName': 'Alexander Cappola'}]

# %% [markdown]
# # 데이터 저장 (csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

data_li = [(info['content'], info['score'], info['thumbsUpCount'], info['at']) for info in raw_data]
# 필요한 정보만 key값으로 선택해서 list 형태로 저장
# mount 과정을 통해서 자신의 구글 드라이브에 데이터를 저장합니다.
# 혹은 경로 설정없이 "application_data.csv"로 저장해도 되지만, 런타임이 끝나면 데이터가 사라질 위험이 있습니다.

with open("/content/drive/MyDrive/application_data.csv", 'wt', encoding='utf-8', newline='') as file:
        csv_writer = csv.writer(file)
        csv_writer.writerow(["contents", "star", "agree", "date"])
        # column name 지정

        for data in data_li:
            csv_writer.writerow(data)

# %%
import pandas as pd

review_df = pd.read_csv("/content/drive/MyDrive/application_data.csv")
review_df
# Out:
#                                                 contents  star  agree  \
# 0      In a word: unfinished. The gameplay is great, ...     2     92
# 1      Really alot of fun. Pretty glitchy for me thou...     4     27
# 2      It's looks pretty interesting overall. I've ba...     4    100
# 3      The gameplay's pretty fun, but the UI needs wo...     3    288
# 4      Overall great fun, but the ads to watch for fr...     4    312
# ...                                                  ...   ...    ...
# 35061  🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯🤯عاااااا...     5      0
# 35062                                i like it 😆😆😆😆😆😆😆😆😆     5      0
# 35063                                              ok ok     3      0
# 35064                                              ok ok     5      0
# 35065                                          عالی عالی     5      0
#
#                       date
# 0      2023-09-20 18:27:49
# 1      2023-10-03 02:45:36
# 2      2023-09-05 22:28:27
# 3      2023-07-30 15:54:29
# 4      2023-08-21 23:33:18
# ...                    ...
# 35061  2020-07-24 11:25:03
# 35062  2019-08-05 17:52:10
# 35063  2019-02-10 09:06:15
# 35064  2019-03-18 09:49:39
# 35065  2021-07-05 19:22:15
#
# [35066 rows x 4 columns]
